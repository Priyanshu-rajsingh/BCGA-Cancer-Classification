# %% [markdown]
# # 02 - Preprocessing
#
# This notebook covers data preprocessing steps for the BCGA Cancer Classification dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Load and preprocess data
# df = pd.read_csv('../data/raw/dataset.csv')
# See src/preprocess.py for the preprocessing pipeline
