# %% [markdown]
# # 01 - Data Exploration
#
# This notebook covers initial exploration of the BCGA Cancer Classification dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Load dataset
# df = pd.read_csv('../data/raw/dataset.csv')
# df.head()
