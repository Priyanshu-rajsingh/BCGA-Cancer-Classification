# %% [markdown]
# # 03 - Model Training
#
# This notebook covers model training and evaluation for BCGA Cancer Classification.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %matplotlib inline

# %%
# Train model
# See src/train.py for the training pipeline
